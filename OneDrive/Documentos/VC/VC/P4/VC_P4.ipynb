# %% [markdown]
# # Práctica 4/4b
#
# En esta práctica, empleamos dos modelos de OCR diferentes para hacer una comparación entre ambos. En este caso, empleamos el mismo código para ambos, cambiando únicamente el modelo para la detección OCR.

# %% [markdown]
# ## EasyOCR

# %% [markdown]
# En este código se hace uso de dos modelos de yolov11, uno preentrenado y otro entrenado únicamente para detectar matrículas de coche, haciendo uso de un dataset descargado de Roboflow.
# Se mantiene una caché de la última detección que se ha hecho de un objeto, por su track_id, para luego poder comparar las nuevas detecciones con la última, y mantener siempre la mejor.
# El proceso de detección y reconocimiento es el siguiente:
# Primero se emplea yolov11 preentrenado para detectar los coches, personas, motocicletas y guaguas. Con cada frame detectado de las clases de interés (coche, motocicleta y guagua), se emplea el segundo modelo de yolov11 para detectar las matrículas. Finalmente, si la bbox de la matrícula es aceptable, se pasa por el modelo de OCR (en este caso EasyOCR) para reconocimiento de caracteres. Antes del reconocimiento se hacen ciertas mejoras a la imagen, para facilitar el reconocimiento por parte del modelo. Como parte del reconocimiento, se hace una comparación del resultado obtenido con el último predicho para dicho objeto, asegurando dejar siempre en la caché el mejor resultado.
# Además, se mantiene una cuenta de los objetos únicos que se han encontrado de cada clase, y se va escribiendo en un csv que refleja el resultado total de la inferencia.

# %%
import cv2
from ultralytics import YOLO
import easyocr

model = YOLO('yolo11n.pt')  # detector + tracker general
model_2 = YOLO('TGC_RBNW/runs/detect/train2/weights/best.pt')  # detector de matrículas

classNames = ["person", "bicycle", "car", "motorcycle", "", "bus"]

vid = cv2.VideoCapture("C0142.MP4")
fps = vid.get(cv2.CAP_PROP_FPS)
width  = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('salida_easyocr.mp4', fourcc, fps, (width, height))

classes_to_count = {"person": 0, "car": 2, "motorcycle": 3, "bus": 5}
seen_ids = {k: set() for k in classes_to_count}
totals_unique = {k: 0 for k in classes_to_count}

reader = easyocr.Reader(['en'], gpu=True)

plate_cache = {}
OCR_TRY_EVERY = 5
MIN_PLATE_AREA = 2500
PAD = 8
ALLOW = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
GOOD_LEN = 5
GOOD_PROB = 0.7

frame_idx = 0

license_plates = 0

while True:
    ret, img = vid.read()
    if not ret:
        break

    # Seguimiento con YOLO: filtra clases relevantes
    results = model.track(img, persist=True, classes=[0, 1, 2, 3, 5])
    r = results[0]
    boxes = r.boxes

    for box in boxes:
        # bbox
        x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())

        # track id
        track_id = str(int(box.id[0].tolist())) if box.id is not None else ''

        # confianza y clase
        conf = float(box.conf[0])
        cls = int(box.cls[0])

        # Seguridad ante índice fuera de rango
        cls_name = classNames[cls] if 0 <= cls < len(classNames) and classNames[cls] else str(cls)

        # CSV base de detección
        csv_text = ",".join((
            str(frame_idx), cls_name, f"{conf:.4f}", track_id,
            str(x1), str(y1), str(x2), str(y2)
        ))

        # Filtro de confianza general
        if conf < 0.6:
            continue

        # Solo contamos únicos si hay tracking id
        if box.id is None:
            continue
        tid = int(box.id[0])

        for name, cid in classes_to_count.items():
            if cls == cid:
                if tid not in seen_ids[name]:
                    seen_ids[name].add(tid)
                    totals_unique[name] += 1
                break

        color = (0, 255, 255) if cls in (2, 3, 5) else (255, 0, 0)
        cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
        label = f"{track_id} {cls_name} {conf:.2f}"
        cv2.putText(img, label, (x1, max(0, y1 - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        if cls_name in ("car", "bus", "motorcycle"):
            img_cropped = img[y1:y2, x1:x2]

            cached = plate_cache.get(track_id, {"text": "", "prob": 0.0, "last_try": -9999})
            have_good_text = (cached["prob"] >= GOOD_PROB and len(cached["text"]) >= GOOD_LEN)
            should_try_ocr = (not have_good_text) and (frame_idx - cached["last_try"] >= OCR_TRY_EVERY)

            best_text, best_prob = "", 0.0
            x1_p = y1_p = x2_p = y2_p = None

            if should_try_ocr and img_cropped.size > 0:
                # Detecta matrícula dentro del vehículo
                plate_results = model_2.predict(img_cropped, classes=[0], verbose=False)
                pr = plate_results[0]
                best_plate_box, best_conf = None, 0.0

                for plate_box in pr.boxes:
                    pconf = float(plate_box.conf[0])
                    if pconf >= best_conf:
                        best_conf = pconf
                        best_plate_box = plate_box

                if best_plate_box is not None:
                    x1_p, y1_p, x2_p, y2_p = map(int, best_plate_box.xyxy[0].tolist())

                    # Padding y límites
                    x1_p = max(0, x1_p - PAD); y1_p = max(0, y1_p - PAD)
                    x2_p = min(img_cropped.shape[1] - 1, x2_p + PAD)
                    y2_p = min(img_cropped.shape[0] - 1, y2_p + PAD)

                    w = max(0, x2_p - x1_p)
                    h = max(0, y2_p - y1_p)

                    if w * h >= MIN_PLATE_AREA and best_conf >= 0.5:
                        cv2.rectangle(img, (x1_p, y1_p), (x2_p, y2_p), (255, 128, 0), 2)
                        plate_roi = img_cropped[y1_p:y2_p, x1_p:x2_p]
                        gray = cv2.cvtColor(plate_roi, cv2.COLOR_BGR2GRAY)

                        # Upscale si ROI es pequeño
                        if max(gray.shape) < 220:
                            gray = cv2.resize(gray, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

                        # Contraste + binarizado suave
                        clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
                        gray = clahe.apply(gray)
                        gray = cv2.GaussianBlur(gray, (3, 3), 0)
                        thr = cv2.adaptiveThreshold(
                            gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 31, 15
                        )

                        ocr = reader.readtext(thr, detail=1, paragraph=False, allowlist=ALLOW)

                        dets = []
                        for (bbox, text, prob) in ocr:
                            if not text:
                                continue
                            xs = [p[0] for p in bbox]
                            dets.append((min(xs), text, float(prob)))

                        dets.sort(key=lambda t: t[0])
                        dets = [d for d in dets if d[2] >= 0.4]

                        if dets:
                            best_text = "".join([d[1] for d in dets]).replace(" ", "").upper()
                            best_prob = sum(d[2] for d in dets) / len(dets)

                        # Actualiza cache sólo si la lectura es razonable y mejor
                        cached_plate = plate_cache.get(track_id, {"text": "", "prob": 0.0, "last_try": -9999})
                        if best_text and len(best_text) >= GOOD_LEN and best_prob >= 0.5 and best_prob > float(cached_plate["prob"]):
                            plate_cache[track_id] = {"text": best_text, "prob": best_prob, "last_try": frame_idx}
                            cv2.putText(img, f"PLATE: {best_text}", (x1, y2 + 20),
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
                            with open("plates_easyocr.txt", "a", encoding="utf-8") as fw:
                                fw.write(f'{best_text}\n')
                        else:
                            # Marca el intento para permitir reintentos futuros
                            cached_plate["last_try"] = frame_idx
                            plate_cache[track_id] = cached_plate
                    else:
                        # ROI demasiado pequeño o conf de placa baja: sólo actualizamos last_try
                        cached_plate = plate_cache.get(track_id, {"text": "", "prob": 0.0, "last_try": -9999})
                        cached_plate["last_try"] = frame_idx
                        plate_cache[track_id] = cached_plate

                # Añade al CSV sólo si hay texto válido y coords válidas
                if best_text and x1_p is not None:
                    csv_text += "," + ",".join((
                        "license_plate", str(x1_p), str(y1_p), str(x2_p), str(y2_p), str(best_text)
                    ))
                    license_plates += 1

            # Mostrar texto cacheado si existe
            cached_text = plate_cache.get(track_id, {}).get("text")
            if cached_text:
                cv2.putText(img, f"PLATE: {cached_text}", (x1, y2 + 20),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

        # Escribe una línea por detección
        with open("results_easyocr.csv", "a", encoding="utf-8") as fw:
            fw.write(f"{csv_text}\n")

    out.write(img)
    frame_idx += 1

print("==== TOTALES ÚNICOS ====")
print("license plates:", license_plates)
print("persons:", totals_unique["person"])
print("cars:", totals_unique["car"])
print("motorcycles:", totals_unique["motorcycle"])
print("buses:", totals_unique["bus"])

vid.release()
out.release()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 0: 384x640 4 cars, 1 bus, 86.6ms
# Speed: 12.6ms preprocess, 86.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 59.8ms
# Speed: 1.9ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 67.3ms
# Speed: 1.7ms preprocess, 67.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 99.8ms
# Speed: 2.8ms preprocess, 99.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 86.5ms
# Speed: 2.1ms preprocess, 86.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 69.3ms
# Speed: 1.6ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# c:\Users\kevin\anaconda3\envs\VC_P4_4_OCR\lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 0: 384x640 4 cars, 1 bus, 70.7ms
# Speed: 1.7ms preprocess, 70.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 91.2ms
# Speed: 1.6ms preprocess, 91.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 60.8ms
# Speed: 1.8ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 65.0ms
# Speed: 1.7ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 66.5ms
# Speed: 1.7ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 66.7ms
# Speed: 2.5ms preprocess, 66.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 65.8ms
# Speed: 1.8ms preprocess, 65.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 86.7ms
# Speed: 2.6ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 72.7ms
# Speed: 1.8ms preprocess, 72.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 59.6ms
# Speed: 1.7ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 79.9ms
# Speed: 1.8ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 113.1ms
# Speed: 3.1ms preprocess, 113.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 80.9ms
# Speed: 2.8ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 99.5ms
# Speed: 3.4ms preprocess, 99.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 101.2ms
# Speed: 3.3ms preprocess, 101.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 94.6ms
# Speed: 2.2ms preprocess, 94.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 81.7ms
# Speed: 2.1ms preprocess, 81.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 72.1ms
# Speed: 2.3ms preprocess, 72.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 77.1ms
# Speed: 1.6ms preprocess, 77.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 74.4ms
# Speed: 2.9ms preprocess, 74.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 67.8ms
# Speed: 1.6ms preprocess, 67.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 59.4ms
# Speed: 1.6ms preprocess, 59.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 58.7ms
# Speed: 1.9ms preprocess, 58.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 59.8ms
# Speed: 1.7ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 80.6ms
# Speed: 2.7ms preprocess, 80.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 91.7ms
# Speed: 1.8ms preprocess, 91.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 286.3ms
# Speed: 4.9ms preprocess, 286.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 339.8ms
# Speed: 8.8ms preprocess, 339.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 334.6ms
# Speed: 8.2ms preprocess, 334.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 386.8ms
# Speed: 8.6ms preprocess, 386.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 452.0ms
# Speed: 7.7ms preprocess, 452.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 676.8ms
# Speed: 8.2ms preprocess, 676.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 358.1ms
# Speed: 9.2ms preprocess, 358.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 453.0ms
# Speed: 11.1ms preprocess, 453.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 755.3ms
# Speed: 30.2ms preprocess, 755.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 739.4ms
# Speed: 8.6ms preprocess, 739.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 475.9ms
# Speed: 10.1ms preprocess, 475.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 453.7ms
# Speed: 16.7ms preprocess, 453.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 375.3ms
# Speed: 9.9ms preprocess, 375.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 728.9ms
# Speed: 9.8ms preprocess, 728.9ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 800.6ms
# Speed: 9.9ms preprocess, 800.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 476.1ms
# Speed: 7.7ms preprocess, 476.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 612.5ms
# Speed: 9.2ms preprocess, 612.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 983.7ms
# Speed: 17.2ms preprocess, 983.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 628.1ms
# Speed: 29.6ms preprocess, 628.1ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 627.9ms
# Speed: 7.3ms preprocess, 627.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 590.8ms
# Speed: 6.4ms preprocess, 590.8ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 653.1ms
# Speed: 6.4ms preprocess, 653.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 598.3ms
# Speed: 6.3ms preprocess, 598.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 864.4ms
# Speed: 30.9ms preprocess, 864.4ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 299.7ms
# Speed: 7.2ms preprocess, 299.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 347.2ms
# Speed: 7.2ms preprocess, 347.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 448.0ms
# Speed: 9.3ms preprocess, 448.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 361.7ms
# Speed: 9.4ms preprocess, 361.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 295.5ms
# Speed: 8.0ms preprocess, 295.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 333.5ms
# Speed: 7.7ms preprocess, 333.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 286.1ms
# Speed: 5.9ms preprocess, 286.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 348.5ms
# Speed: 8.5ms preprocess, 348.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 349.6ms
# Speed: 6.9ms preprocess, 349.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 330.4ms
# Speed: 9.3ms preprocess, 330.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 404.6ms
# Speed: 7.3ms preprocess, 404.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 571.0ms
# Speed: 9.7ms preprocess, 571.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 307.7ms
# Speed: 7.1ms preprocess, 307.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 387.1ms
# Speed: 8.9ms preprocess, 387.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 376.1ms
# Speed: 7.5ms preprocess, 376.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 371.7ms
# Speed: 7.7ms preprocess, 371.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 460.3ms
# Speed: 8.3ms preprocess, 460.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 378.1ms
# Speed: 7.7ms preprocess, 378.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 368.5ms
# Speed: 8.7ms preprocess, 368.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 902.9ms
# Speed: 10.4ms preprocess, 902.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 629.8ms
# Speed: 8.4ms preprocess, 629.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 911.4ms
# Speed: 9.9ms preprocess, 911.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 703.3ms
# Speed: 65.3ms preprocess, 703.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 896.8ms
# Speed: 8.4ms preprocess, 896.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 634.0ms
# Speed: 8.9ms preprocess, 634.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 932.0ms
# Speed: 8.8ms preprocess, 932.0ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 902.7ms
# Speed: 7.4ms preprocess, 902.7ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 816.6ms
# Speed: 12.8ms preprocess, 816.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 881.5ms
# Speed: 13.7ms preprocess, 881.5ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 386.5ms
# Speed: 7.6ms preprocess, 386.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 663.7ms
# Speed: 7.3ms preprocess, 663.7ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 604.6ms
# Speed: 15.1ms preprocess, 604.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 429.9ms
# Speed: 12.2ms preprocess, 429.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 793.3ms
# Speed: 7.9ms preprocess, 793.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 817.5ms
# Speed: 12.2ms preprocess, 817.5ms inference, 21.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 566.4ms
# Speed: 11.6ms preprocess, 566.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 333.5ms
# Speed: 8.5ms preprocess, 333.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 906.1ms
# Speed: 7.5ms preprocess, 906.1ms inference, 43.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 bus, 1087.1ms
# Speed: 17.3ms preprocess, 1087.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 bus, 979.0ms
# Speed: 8.8ms preprocess, 979.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 886.7ms
# Speed: 18.5ms preprocess, 886.7ms inference, 19.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 774.4ms
# Speed: 6.4ms preprocess, 774.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1015.7ms
# Speed: 35.5ms preprocess, 1015.7ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 764.7ms
# Speed: 26.1ms preprocess, 764.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 916.3ms
# Speed: 7.3ms preprocess, 916.3ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 946.8ms
# Speed: 19.3ms preprocess, 946.8ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 604.0ms
# Speed: 13.8ms preprocess, 604.0ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 760.6ms
# Speed: 9.0ms preprocess, 760.6ms inference, 23.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 362.7ms
# Speed: 6.4ms preprocess, 362.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 660.7ms
# Speed: 8.5ms preprocess, 660.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 500.6ms
# Speed: 9.9ms preprocess, 500.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 658.1ms
# Speed: 26.9ms preprocess, 658.1ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 377.2ms
# Speed: 9.3ms preprocess, 377.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 358.1ms
# Speed: 7.9ms preprocess, 358.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 378.6ms
# Speed: 7.6ms preprocess, 378.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 405.6ms
# Speed: 11.1ms preprocess, 405.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 381.8ms
# Speed: 8.1ms preprocess, 381.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 387.2ms
# Speed: 7.1ms preprocess, 387.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 350.2ms
# Speed: 7.0ms preprocess, 350.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 379.1ms
# Speed: 7.0ms preprocess, 379.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 412.3ms
# Speed: 6.6ms preprocess, 412.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 466.0ms
# Speed: 7.0ms preprocess, 466.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 359.7ms
# Speed: 7.3ms preprocess, 359.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 385.1ms
# Speed: 9.6ms preprocess, 385.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 311.6ms
# Speed: 8.0ms preprocess, 311.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 318.5ms
# Speed: 6.7ms preprocess, 318.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 306.4ms
# Speed: 7.1ms preprocess, 306.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 328.2ms
# Speed: 7.9ms preprocess, 328.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 614.8ms
# Speed: 7.4ms preprocess, 614.8ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 797.2ms
# Speed: 9.1ms preprocess, 797.2ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 943.4ms
# Speed: 14.5ms preprocess, 943.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 898.7ms
# Speed: 9.3ms preprocess, 898.7ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 408.2ms
# Speed: 8.8ms preprocess, 408.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 808.5ms
# Speed: 11.4ms preprocess, 808.5ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 980.5ms
# Speed: 23.2ms preprocess, 980.5ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 985.9ms
# Speed: 19.1ms preprocess, 985.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 778.9ms
# Speed: 9.1ms preprocess, 778.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 593.1ms
# Speed: 16.4ms preprocess, 593.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 672.9ms
# Speed: 6.6ms preprocess, 672.9ms inference, 25.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 662.0ms
# Speed: 10.5ms preprocess, 662.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 448.4ms
# Speed: 13.3ms preprocess, 448.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 536.9ms
# Speed: 7.4ms preprocess, 536.9ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 443.4ms
# Speed: 24.2ms preprocess, 443.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 458.6ms
# Speed: 7.4ms preprocess, 458.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 419.5ms
# Speed: 7.0ms preprocess, 419.5ms inference, 21.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 896.7ms
# Speed: 8.5ms preprocess, 896.7ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 446.3ms
# Speed: 7.5ms preprocess, 446.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 307.6ms
# Speed: 9.8ms preprocess, 307.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 55.9ms
# Speed: 1.7ms preprocess, 55.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 62.4ms
# Speed: 1.7ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 65.0ms
# Speed: 1.4ms preprocess, 65.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 59.5ms
# Speed: 1.7ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 55.8ms
# Speed: 1.7ms preprocess, 55.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 58.5ms
# Speed: 1.7ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 61.4ms
# Speed: 1.5ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 58.3ms
# Speed: 1.4ms preprocess, 58.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 91.1ms
# Speed: 1.6ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 62.3ms
# Speed: 1.9ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 53.5ms
# Speed: 1.5ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 48.4ms
# Speed: 1.6ms preprocess, 48.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 56.5ms
# Speed: 1.6ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.6ms
# Speed: 1.4ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 61.4ms
# Speed: 1.6ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.3ms
# Speed: 1.8ms preprocess, 50.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 54.7ms
# Speed: 1.6ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 51.4ms
# Speed: 1.5ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 63.3ms
# Speed: 1.5ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 57.1ms
# Speed: 1.9ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 60.1ms
# Speed: 1.7ms preprocess, 60.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 68.4ms
# Speed: 1.5ms preprocess, 68.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 62.8ms
# Speed: 1.7ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 59.3ms
# Speed: 1.8ms preprocess, 59.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 56.6ms
# Speed: 1.7ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 55.5ms
# Speed: 1.5ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 58.9ms
# Speed: 2.3ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 58.9ms
# Speed: 2.3ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 62.2ms
# Speed: 2.4ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 67.9ms
# Speed: 2.4ms preprocess, 67.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 56.3ms
# Speed: 2.2ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 60.7ms
# Speed: 2.4ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 55.9ms
# Speed: 2.2ms preprocess, 55.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.5ms
# Speed: 2.1ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 63.3ms
# Speed: 1.6ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 52.6ms
# Speed: 1.5ms preprocess, 52.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 62.2ms
# Speed: 1.4ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.5ms
# Speed: 1.5ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 51.0ms
# Speed: 1.6ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 49.9ms
# Speed: 2.4ms preprocess, 49.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.0ms
# Speed: 1.5ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 49.5ms
# Speed: 1.7ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 52.3ms
# Speed: 1.6ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 55.2ms
# Speed: 1.6ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 56.6ms
# Speed: 1.7ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 55.9ms
# Speed: 2.0ms preprocess, 55.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 61.9ms
# Speed: 2.1ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 57.0ms
# Speed: 2.2ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 55.5ms
# Speed: 2.1ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 55.8ms
# Speed: 1.6ms preprocess, 55.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 65.2ms
# Speed: 1.5ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.5ms
# Speed: 1.8ms preprocess, 54.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.5ms
# Speed: 1.6ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.1ms
# Speed: 1.9ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.5ms
# Speed: 1.6ms preprocess, 52.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.0ms
# Speed: 1.6ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.9ms
# Speed: 1.6ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 65.7ms
# Speed: 3.1ms preprocess, 65.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 74.7ms
# Speed: 1.5ms preprocess, 74.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 81.1ms
# Speed: 2.1ms preprocess, 81.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 54.6ms
# Speed: 1.5ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 47.1ms
# Speed: 1.5ms preprocess, 47.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 59.4ms
# Speed: 1.5ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 58.8ms
# Speed: 1.6ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 51.6ms
# Speed: 1.8ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 62.4ms
# Speed: 2.2ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 61.7ms
# Speed: 1.8ms preprocess, 61.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 55.3ms
# Speed: 1.8ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 60.6ms
# Speed: 1.8ms preprocess, 60.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 64.9ms
# Speed: 2.1ms preprocess, 64.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 54.7ms
# Speed: 1.8ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 58.1ms
# Speed: 1.9ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 64.7ms
# Speed: 2.3ms preprocess, 64.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 61.0ms
# Speed: 2.3ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 59.4ms
# Speed: 1.9ms preprocess, 59.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 59.1ms
# Speed: 1.9ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 58.9ms
# Speed: 1.8ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 64.4ms
# Speed: 1.8ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 55.1ms
# Speed: 2.4ms preprocess, 55.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 59.9ms
# Speed: 2.4ms preprocess, 59.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 60.4ms
# Speed: 1.6ms preprocess, 60.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 52.7ms
# Speed: 1.5ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 64.1ms
# Speed: 1.5ms preprocess, 64.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 55.5ms
# Speed: 1.6ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 60.2ms
# Speed: 1.6ms preprocess, 60.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 61.4ms
# Speed: 2.4ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 68.6ms
# Speed: 2.3ms preprocess, 68.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 58.4ms
# Speed: 2.3ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 59.0ms
# Speed: 2.1ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 59.9ms
# Speed: 2.2ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 57.0ms
# Speed: 2.2ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 54.1ms
# Speed: 2.4ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 66.2ms
# Speed: 2.1ms preprocess, 66.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 62.7ms
# Speed: 2.3ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 56.4ms
# Speed: 2.2ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 67.5ms
# Speed: 2.1ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 60.6ms
# Speed: 1.8ms preprocess, 60.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 55.6ms
# Speed: 1.6ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 54.9ms
# Speed: 1.6ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 56.1ms
# Speed: 1.8ms preprocess, 56.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 61.2ms
# Speed: 1.6ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 53.5ms
# Speed: 1.7ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 55.8ms
# Speed: 1.5ms preprocess, 55.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 59.5ms
# Speed: 1.5ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 57.0ms
# Speed: 1.5ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 53.8ms
# Speed: 1.8ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 54.0ms
# Speed: 1.7ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 54.6ms
# Speed: 1.6ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 58.8ms
# Speed: 1.6ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 57.2ms
# Speed: 1.5ms preprocess, 57.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 56.1ms
# Speed: 1.7ms preprocess, 56.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 57.2ms
# Speed: 1.5ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 54.3ms
# Speed: 1.5ms preprocess, 54.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.2ms
# Speed: 1.6ms preprocess, 53.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 48.8ms
# Speed: 1.4ms preprocess, 48.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 51.7ms
# Speed: 1.7ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 62.5ms
# Speed: 1.6ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 55.5ms
# Speed: 1.7ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.4ms
# ...
# Speed: 1.5ms preprocess, 75.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 58.7ms
# Speed: 1.7ms preprocess, 58.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 51.7ms
# Speed: 1.7ms preprocess, 51.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 83.3ms
# Speed: 1.6ms preprocess, 83.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 54.0ms
# Speed: 1.5ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 69.7ms
# Speed: 1.8ms preprocess, 69.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.3ms
# Speed: 1.6ms preprocess, 53.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 84.8ms
# Speed: 1.8ms preprocess, 84.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.0ms
# Speed: 1.6ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 90.8ms
# Speed: 2.9ms preprocess, 90.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 51.3ms
# Speed: 1.9ms preprocess, 51.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 55.7ms
# Speed: 1.6ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 49.9ms
# Speed: 1.6ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 89.6ms
# Speed: 2.7ms preprocess, 89.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 82.3ms
# Speed: 1.6ms preprocess, 82.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 82.9ms
# Speed: 1.7ms preprocess, 82.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 65.2ms
# Speed: 1.5ms preprocess, 65.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 67.8ms
# Speed: 1.6ms preprocess, 67.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 72.9ms
# Speed: 1.8ms preprocess, 72.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 56.6ms
# Speed: 1.7ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 72.6ms
# Speed: 1.7ms preprocess, 72.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 73.5ms
# Speed: 1.8ms preprocess, 73.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 59.8ms
# Speed: 1.9ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 74.7ms
# Speed: 1.6ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 66.2ms
# Speed: 1.7ms preprocess, 66.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 68.5ms
# Speed: 1.7ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 64.3ms
# Speed: 1.7ms preprocess, 64.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 71.2ms
# Speed: 1.6ms preprocess, 71.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 59.7ms
# Speed: 1.6ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 63.4ms
# Speed: 1.5ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 56.7ms
# Speed: 1.5ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 71.0ms
# Speed: 1.6ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 77.1ms
# Speed: 1.7ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 57.2ms
# Speed: 1.5ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 65.5ms
# Speed: 1.7ms preprocess, 65.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 56.9ms
# Speed: 1.7ms preprocess, 56.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 55.4ms
# Speed: 1.6ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 58.4ms
# Speed: 1.6ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 57.4ms
# Speed: 1.6ms preprocess, 57.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 71.3ms
# Speed: 1.6ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 54.9ms
# Speed: 1.6ms preprocess, 54.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 55.6ms
# Speed: 1.6ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 55.0ms
# Speed: 1.7ms preprocess, 55.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 58.9ms
# Speed: 1.5ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 58.8ms
# Speed: 1.5ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 55.9ms
# Speed: 1.5ms preprocess, 55.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 57.6ms
# Speed: 1.6ms preprocess, 57.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 59.5ms
# Speed: 1.9ms preprocess, 59.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 60.8ms
# Speed: 1.5ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 54.7ms
# Speed: 1.6ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 54.6ms
# Speed: 1.5ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 59.8ms
# Speed: 1.6ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 59.5ms
# Speed: 1.6ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.6ms
# Speed: 1.8ms preprocess, 53.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 66.6ms
# Speed: 1.8ms preprocess, 66.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.2ms
# Speed: 1.6ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 52.3ms
# Speed: 1.6ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 54.1ms
# Speed: 1.7ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 67.5ms
# Speed: 1.5ms preprocess, 67.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 50.9ms
# Speed: 1.7ms preprocess, 50.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 61.1ms
# Speed: 1.6ms preprocess, 61.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.3ms
# Speed: 1.7ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 55.1ms
# Speed: 1.6ms preprocess, 55.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 49.2ms
# Speed: 1.5ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 49.7ms
# Speed: 1.5ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 51.1ms
# Speed: 1.6ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 49.5ms
# Speed: 1.5ms preprocess, 49.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 55.0ms
# Speed: 1.6ms preprocess, 55.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 54.4ms
# Speed: 1.8ms preprocess, 54.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 55.0ms
# Speed: 1.7ms preprocess, 55.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 51.8ms
# Speed: 1.4ms preprocess, 51.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 49.0ms
# Speed: 1.5ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 49.2ms
# Speed: 1.5ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 49.3ms
# Speed: 1.7ms preprocess, 49.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 53.7ms
# Speed: 1.7ms preprocess, 53.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 55.4ms
# Speed: 1.8ms preprocess, 55.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 60.3ms
# Speed: 1.8ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 51.6ms
# Speed: 1.7ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 58.2ms
# Speed: 1.7ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 57.2ms
# Speed: 1.7ms preprocess, 57.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 58.9ms
# Speed: 1.7ms preprocess, 58.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 53.7ms
# Speed: 1.8ms preprocess, 53.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 77.4ms
# Speed: 1.7ms preprocess, 77.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 53.3ms
# Speed: 1.6ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# ==== TOTALES ÚNICOS ====
# license plates: 18
# persons: 21
# cars: 81
# motorcycles: 2
# buses: 3
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 200
#     198 vid.release()
#     199 out.release()
# --> 200 cv2.destroyAllWindows()
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %% [markdown]
# ## PyTesseract

# %% [markdown]
# En esta celda lo que realizamos son pequeños cambios respecto al código anterior, los justos para cambiar el modelo, de EasyOCR a PyTesseract. El resto del código funciona exactamente del mismo modo, a diferencia del modelo de OCR empleado.

# %%
import cv2
from ultralytics import YOLO
import pytesseract
from pytesseract import Output

pytesseract.pytesseract.tesseract_cmd = r"C:/Users/kevin/AppData/Local/Programs/Tesseract-OCR/tesseract.exe"
model = YOLO('yolo11n.pt')
model_2 = YOLO('TGC_RBNW/runs/detect/train2/weights/best.pt')

classNames = ["person", "bicycle", "car", "motorcycle", "", "bus"]

vid = cv2.VideoCapture("C0142.MP4")
fps = vid.get(cv2.CAP_PROP_FPS)
width  = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('salida_tesseract_uv.mp4', fourcc, fps, (width, height))

classes_to_count = {"person": 0, "car": 2, "motorcycle": 3, "bus": 5}
seen_ids = {k: set() for k in classes_to_count}
totals_unique = {k: 0 for k in classes_to_count}
license_plates = 0

plate_cache = {}
OCR_TRY_EVERY = 5
MIN_PLATE_AREA = 2500
PAD = 8
ALLOW = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"
GOOD_LEN = 5
GOOD_PROB = 0.55

TESS_PSM = 7
TS_CONFIG = f'-l eng --oem 3 --psm {TESS_PSM} -c tessedit_char_whitelist={ALLOW}'

frame_idx = 0

while True:
    ret, img = vid.read()
    if not ret:
        break

    # Seguimiento con YOLO: filtra clases relevantes
    results = model.track(img, persist=True, classes=[0, 1, 2, 3, 5])
    r = results[0]
    boxes = r.boxes

    for box in boxes:
        # bbox
        x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())

        # track id
        track_id = str(int(box.id[0].tolist())) if box.id is not None else ''

        # confianza y clase
        conf = float(box.conf[0])
        cls = int(box.cls[0])

        cls_name = classNames[cls] if 0 <= cls < len(classNames) and classNames[cls] else str(cls)
        
        csv_text = ",".join((
            str(frame_idx), cls_name, f"{conf:.4f}", track_id,
            str(x1), str(y1), str(x2), str(y2)
        ))

        # Filtro de confianza general
        if conf < 0.6:
            continue

        # Solo contamos únicos si hay tracking id
        if box.id is None:
            continue
        tid = int(box.id[0])

        for name, cid in classes_to_count.items():
            if cls == cid:
                if tid not in seen_ids[name]:
                    seen_ids[name].add(tid)
                    totals_unique[name] += 1
                break

        # Dibujo del bbox
        color = (0, 255, 255) if cls in (2, 3, 5) else (255, 0, 0)
        cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
        label = f"{track_id} {cls_name} {conf:.2f}"
        cv2.putText(img, label, (x1, max(0, y1 - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        
        if cls_name in ("car", "bus", "motorcycle"):
            img_cropped = img[y1:y2, x1:x2]
            
            cached = plate_cache.get(track_id, {"text": "", "prob": 0.0, "last_try": -9999})
            have_good_text = (cached["prob"] >= GOOD_PROB and len(cached["text"]) >= GOOD_LEN)
            should_try_ocr = (not have_good_text) and (frame_idx - cached["last_try"] >= OCR_TRY_EVERY)
            
            best_text, best_prob = "", 0.0
            x1_p = y1_p = x2_p = y2_p = None

            if should_try_ocr and img_cropped.size > 0:
                # Detecta matrícula dentro del vehículo
                plate_results = model_2.predict(img_cropped, classes=[0], verbose=False)
                pr = plate_results[0]
                best_plate_box, best_conf = None, 0.0

                for plate_box in pr.boxes:
                    pconf = float(plate_box.conf[0])
                    if pconf >= best_conf:
                        best_conf = pconf
                        best_plate_box = plate_box

                if best_plate_box is not None:
                    x1_p, y1_p, x2_p, y2_p = map(int, best_plate_box.xyxy[0].tolist())

                    # Padding y límites
                    x1_p = max(0, x1_p - PAD); y1_p = max(0, y1_p - PAD)
                    x2_p = min(img_cropped.shape[1] - 1, x2_p + PAD)
                    y2_p = min(img_cropped.shape[0] - 1, y2_p + PAD)

                    w = max(0, x2_p - x1_p)
                    h = max(0, y2_p - y1_p)

                    if w * h >= MIN_PLATE_AREA and best_conf >= 0.5:
                        plate_roi = img_cropped[y1_p:y2_p, x1_p:x2_p]
                        gray = cv2.cvtColor(plate_roi, cv2.COLOR_BGR2GRAY)

                        # Upscale si ROI es pequeño
                        if max(gray.shape) < 220:
                            gray = cv2.resize(gray, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

                        # Contraste + binarizado suave
                        clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
                        gray = clahe.apply(gray)
                        gray = cv2.GaussianBlur(gray, (3, 3), 0)
                        thr = cv2.adaptiveThreshold(
                            gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 31, 15
                        )
                        
                        data = pytesseract.image_to_data(
                            thr, lang='eng', config=TS_CONFIG, output_type=Output.DICT
                        )
                        
                        dets = []
                        n = len(data.get('text', []))
                        for i in range(n):
                            txt = data['text'][i].strip()
                            try:
                                conf_i = float(data['conf'][i])
                            except:
                                conf_i = -1.0
                            if not txt or conf_i < 0:
                                continue
                            left_i = float(data.get('left', [0]*n)[i])
                            
                            txt = "".join([c for c in txt.upper() if c in ALLOW])
                            if not txt:
                                continue
                            # Tesseract da conf en 0..100 -> normalizamos a 0..1
                            dets.append((left_i, txt, conf_i / 100.0))

                        dets.sort(key=lambda t: t[0])
                        dets = [d for d in dets if d[2] >= 0.4]

                        if dets:
                            best_text = "".join([d[1] for d in dets]).replace(" ", "").upper()
                            best_prob = sum(d[2] for d in dets) / len(dets)
                        
                        cached_plate = plate_cache.get(track_id, {"text": "", "prob": 0.0, "last_try": -9999})
                        if best_text and best_prob >= 0.5 and best_prob > float(cached_plate["prob"]):
                            plate_cache[track_id] = {"text": best_text, "prob": best_prob, "last_try": frame_idx}
                            license_plates += 1
                            cv2.putText(img, f"PLATE: {best_text}", (x1, y2 + 20),
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
                        else:
                            # Marca el intento para permitir reintentos futuros
                            cached_plate["last_try"] = frame_idx
                            plate_cache[track_id] = cached_plate
                    else:
                        # ROI demasiado pequeño o conf de placa baja: sólo actualiza last_try
                        cached_plate = plate_cache.get(track_id, {"text": "", "prob": 0.0, "last_try": -9999})
                        cached_plate["last_try"] = frame_idx
                        plate_cache[track_id] = cached_plate

                # Añade al CSV sólo si hay texto válido y coords válidas
                if best_text and x1_p is not None:
                    csv_text += "," + ",".join((
                        "license_plate", str(x1_p), str(y1_p), str(x2_p), str(y2_p), str(best_text)
                    ))

            cached_text = plate_cache.get(track_id, {}).get("text")
            if cached_text:
                cv2.putText(img, f"PLATE: {cached_text}", (x1, y2 + 20),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

        # Escribe una línea por detección
        with open("results_tesseract_uv.csv", "a", encoding="utf-8") as fw:
            fw.write(f"{csv_text}\n")

    out.write(img)
    frame_idx += 1

print("==== TOTALES ÚNICOS ====")
print("license plates:", license_plates)
print("persons:", totals_unique["person"])
print("cars:", totals_unique["car"])
print("motorcycles:", totals_unique["motorcycle"])
print("buses:", totals_unique["bus"])

vid.release()
out.release()
# Out:
# 0: 384x640 4 cars, 1 bus, 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 57.2ms
# Speed: 1.7ms preprocess, 57.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 55.0ms
# Speed: 1.6ms preprocess, 55.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 52.8ms
# Speed: 1.7ms preprocess, 52.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 52.3ms
# Speed: 2.4ms preprocess, 52.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 65.5ms
# Speed: 1.7ms preprocess, 65.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 63.3ms
# Speed: 1.8ms preprocess, 63.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 61.4ms
# Speed: 1.6ms preprocess, 61.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 60.3ms
# Speed: 1.7ms preprocess, 60.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 54.5ms
# Speed: 1.7ms preprocess, 54.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 57.7ms
# Speed: 1.6ms preprocess, 57.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 60.1ms
# Speed: 1.8ms preprocess, 60.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 58.9ms
# Speed: 1.8ms preprocess, 58.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 58.1ms
# Speed: 1.7ms preprocess, 58.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 53.6ms
# Speed: 1.8ms preprocess, 53.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 51.1ms
# Speed: 1.9ms preprocess, 51.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 49.4ms
# Speed: 1.7ms preprocess, 49.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 48.5ms
# Speed: 1.6ms preprocess, 48.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 59.8ms
# Speed: 1.6ms preprocess, 59.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 52.4ms
# Speed: 1.6ms preprocess, 52.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 46.5ms
# Speed: 1.8ms preprocess, 46.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 48.8ms
# Speed: 1.6ms preprocess, 48.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 49.2ms
# Speed: 1.6ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 48.6ms
# Speed: 2.5ms preprocess, 48.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 49.9ms
# Speed: 1.8ms preprocess, 49.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 58.6ms
# Speed: 1.7ms preprocess, 58.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 61.6ms
# Speed: 1.9ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 71.4ms
# Speed: 1.8ms preprocess, 71.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 71.7ms
# Speed: 2.0ms preprocess, 71.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 54.1ms
# Speed: 2.7ms preprocess, 54.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 52.8ms
# Speed: 1.8ms preprocess, 52.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 57.3ms
# Speed: 2.8ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 56.0ms
# Speed: 2.1ms preprocess, 56.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.9ms
# Speed: 1.6ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.4ms
# Speed: 2.1ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 60.8ms
# Speed: 1.9ms preprocess, 60.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 58.4ms
# Speed: 2.1ms preprocess, 58.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.2ms
# Speed: 1.9ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 54.0ms
# Speed: 1.6ms preprocess, 54.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.5ms
# Speed: 1.6ms preprocess, 48.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.7ms
# Speed: 1.7ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 66.2ms
# Speed: 1.6ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 56.9ms
# Speed: 2.2ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 55.6ms
# Speed: 1.5ms preprocess, 55.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.4ms
# Speed: 1.6ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 47.9ms
# Speed: 1.7ms preprocess, 47.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 47.9ms
# Speed: 1.5ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.9ms
# Speed: 1.7ms preprocess, 51.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.0ms
# Speed: 1.6ms preprocess, 48.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 59.7ms
# Speed: 1.7ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 52.5ms
# Speed: 1.6ms preprocess, 52.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 50.2ms
# Speed: 1.8ms preprocess, 50.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.7ms
# Speed: 1.6ms preprocess, 51.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 47.9ms
# Speed: 1.6ms preprocess, 47.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.6ms
# Speed: 1.6ms preprocess, 48.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 57.3ms
# Speed: 1.7ms preprocess, 57.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 56.5ms
# Speed: 1.8ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 59.1ms
# Speed: 1.6ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.1ms
# Speed: 1.6ms preprocess, 51.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.8ms
# Speed: 2.0ms preprocess, 48.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 51.9ms
# Speed: 1.5ms preprocess, 51.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 54.8ms
# Speed: 2.3ms preprocess, 54.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 60.7ms
# Speed: 2.3ms preprocess, 60.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 65.8ms
# Speed: 1.8ms preprocess, 65.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 59.4ms
# Speed: 2.5ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 52.7ms
# Speed: 1.6ms preprocess, 52.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 bus, 55.0ms
# Speed: 2.4ms preprocess, 55.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 bus, 57.2ms
# Speed: 2.5ms preprocess, 57.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 51.5ms
# Speed: 1.6ms preprocess, 51.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 52.2ms
# Speed: 1.9ms preprocess, 52.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 55.7ms
# Speed: 1.6ms preprocess, 55.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 52.1ms
# Speed: 1.9ms preprocess, 52.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.2ms
# Speed: 1.7ms preprocess, 53.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 52.7ms
# Speed: 1.6ms preprocess, 52.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.5ms
# Speed: 1.6ms preprocess, 53.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.9ms
# Speed: 1.5ms preprocess, 53.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 55.8ms
# Speed: 1.6ms preprocess, 55.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 55.5ms
# Speed: 1.5ms preprocess, 55.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 54.8ms
# Speed: 1.9ms preprocess, 54.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 60.0ms
# Speed: 1.6ms preprocess, 60.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 52.1ms
# Speed: 1.6ms preprocess, 52.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 56.4ms
# Speed: 1.5ms preprocess, 56.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 70.4ms
# Speed: 1.8ms preprocess, 70.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 56.3ms
# Speed: 1.5ms preprocess, 56.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 53.7ms
# Speed: 1.7ms preprocess, 53.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 55.4ms
# Speed: 1.7ms preprocess, 55.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 60.5ms
# Speed: 1.7ms preprocess, 60.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 52.0ms
# Speed: 1.7ms preprocess, 52.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 64.7ms
# Speed: 1.8ms preprocess, 64.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 54.0ms
# Speed: 1.7ms preprocess, 54.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 52.7ms
# Speed: 1.6ms preprocess, 52.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.4ms
# Speed: 1.9ms preprocess, 50.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 60.3ms
# Speed: 1.6ms preprocess, 60.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.4ms
# Speed: 1.6ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 53.2ms
# Speed: 2.1ms preprocess, 53.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 55.8ms
# Speed: 1.6ms preprocess, 55.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 55.8ms
# Speed: 1.5ms preprocess, 55.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 57.8ms
# Speed: 1.6ms preprocess, 57.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.6ms
# Speed: 1.7ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.3ms
# Speed: 1.6ms preprocess, 49.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 51.1ms
# Speed: 1.7ms preprocess, 51.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 48.2ms
# Speed: 1.7ms preprocess, 48.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.2ms
# Speed: 1.6ms preprocess, 52.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 60.1ms
# Speed: 1.7ms preprocess, 60.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 48.7ms
# Speed: 1.5ms preprocess, 48.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 55.6ms
# Speed: 1.6ms preprocess, 55.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 54.7ms
# Speed: 1.6ms preprocess, 54.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 55.2ms
# Speed: 1.5ms preprocess, 55.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 58.7ms
# Speed: 1.6ms preprocess, 58.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 52.2ms
# Speed: 1.5ms preprocess, 52.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 49.6ms
# Speed: 1.5ms preprocess, 49.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.4ms
# Speed: 1.7ms preprocess, 52.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 56.2ms
# Speed: 1.7ms preprocess, 56.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.4ms
# Speed: 1.7ms preprocess, 52.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.0ms
# Speed: 1.7ms preprocess, 52.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 57.2ms
# Speed: 1.9ms preprocess, 57.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 51.4ms
# Speed: 1.6ms preprocess, 51.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.9ms
# Speed: 1.8ms preprocess, 53.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 70.6ms
# Speed: 1.5ms preprocess, 70.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.4ms
# Speed: 1.8ms preprocess, 51.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.2ms
# Speed: 1.7ms preprocess, 51.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.7ms
# Speed: 1.8ms preprocess, 49.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.8ms
# Speed: 1.7ms preprocess, 50.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 48.8ms
# Speed: 1.7ms preprocess, 48.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 56.8ms
# Speed: 1.6ms preprocess, 56.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 58.5ms
# Speed: 1.8ms preprocess, 58.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 55.5ms
# Speed: 1.6ms preprocess, 55.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 52.8ms
# Speed: 1.7ms preprocess, 52.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 52.4ms
# Speed: 1.6ms preprocess, 52.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.3ms
# Speed: 1.6ms preprocess, 49.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.8ms
# Speed: 1.8ms preprocess, 49.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 62.0ms
# Speed: 2.5ms preprocess, 62.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.7ms
# Speed: 2.4ms preprocess, 51.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 52.9ms
# Speed: 2.6ms preprocess, 52.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 56.2ms
# Speed: 2.7ms preprocess, 56.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.2ms
# Speed: 2.3ms preprocess, 53.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 55.3ms
# Speed: 2.3ms preprocess, 55.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 53.7ms
# Speed: 2.4ms preprocess, 53.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 58.4ms
# Speed: 1.6ms preprocess, 58.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.4ms
# Speed: 1.6ms preprocess, 49.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.6ms
# Speed: 1.7ms preprocess, 50.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 48.7ms
# Speed: 1.7ms preprocess, 48.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 54.2ms
# Speed: 1.6ms preprocess, 54.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 49.4ms
# Speed: 2.1ms preprocess, 49.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 50.2ms
# Speed: 1.6ms preprocess, 50.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 48.0ms
# Speed: 1.7ms preprocess, 48.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.7ms
# Speed: 2.5ms preprocess, 54.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.7ms
# Speed: 1.6ms preprocess, 51.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.0ms
# Speed: 1.6ms preprocess, 53.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 58.3ms
# Speed: 1.7ms preprocess, 58.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.8ms
# Speed: 1.8ms preprocess, 54.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 61.6ms
# Speed: 2.4ms preprocess, 61.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 54.9ms
# Speed: 2.6ms preprocess, 54.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.2ms
# Speed: 2.4ms preprocess, 54.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.3ms
# Speed: 2.3ms preprocess, 54.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 58.6ms
# Speed: 2.5ms preprocess, 58.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 49.9ms
# Speed: 1.7ms preprocess, 49.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 47.6ms
# Speed: 1.6ms preprocess, 47.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.8ms
# Speed: 1.5ms preprocess, 52.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 53.5ms
# Speed: 1.7ms preprocess, 53.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.6ms
# Speed: 1.5ms preprocess, 51.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 49.9ms
# Speed: 1.5ms preprocess, 49.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.0ms
# Speed: 1.5ms preprocess, 51.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.4ms
# Speed: 1.6ms preprocess, 50.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 58.7ms
# Speed: 1.6ms preprocess, 58.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 48.7ms
# Speed: 1.6ms preprocess, 48.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 59.7ms
# Speed: 1.7ms preprocess, 59.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 62.7ms
# Speed: 1.7ms preprocess, 62.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 50.9ms
# Speed: 1.5ms preprocess, 50.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 52.8ms
# Speed: 2.2ms preprocess, 52.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 56.5ms
# Speed: 1.7ms preprocess, 56.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 53.6ms
# Speed: 1.7ms preprocess, 53.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 63.8ms
# Speed: 1.8ms preprocess, 63.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 63.7ms
# Speed: 1.6ms preprocess, 63.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 54.6ms
# Speed: 1.9ms preprocess, 54.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 70.4ms
# Speed: 1.8ms preprocess, 70.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 122.9ms
# Speed: 2.1ms preprocess, 122.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 518.2ms
# Speed: 7.7ms preprocess, 518.2ms inference, 36.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 452.8ms
# Speed: 16.2ms preprocess, 452.8ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 410.9ms
# Speed: 10.1ms preprocess, 410.9ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 560.7ms
# Speed: 17.7ms preprocess, 560.7ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 378.0ms
# Speed: 22.7ms preprocess, 378.0ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 361.8ms
# Speed: 8.8ms preprocess, 361.8ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 450.6ms
# Speed: 10.5ms preprocess, 450.6ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 534.7ms
# Speed: 9.4ms preprocess, 534.7ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 761.1ms
# Speed: 10.5ms preprocess, 761.1ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 352.8ms
# Speed: 9.0ms preprocess, 352.8ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 503.7ms
# Speed: 9.4ms preprocess, 503.7ms inference, 21.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 518.6ms
# Speed: 14.4ms preprocess, 518.6ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 490.0ms
# Speed: 9.5ms preprocess, 490.0ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 820.7ms
# Speed: 9.3ms preprocess, 820.7ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 940.1ms
# Speed: 12.2ms preprocess, 940.1ms inference, 26.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 538.8ms
# Speed: 12.7ms preprocess, 538.8ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 740.0ms
# Speed: 10.5ms preprocess, 740.0ms inference, 25.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 439.0ms
# Speed: 10.0ms preprocess, 439.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 578.6ms
# Speed: 9.6ms preprocess, 578.6ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 511.4ms
# Speed: 10.0ms preprocess, 511.4ms inference, 27.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 833.2ms
# Speed: 12.5ms preprocess, 833.2ms inference, 27.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 328.7ms
# Speed: 10.1ms preprocess, 328.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 61.9ms
# Speed: 2.2ms preprocess, 61.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 61.4ms
# Speed: 2.4ms preprocess, 61.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 79.4ms
# Speed: 2.7ms preprocess, 79.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 65.3ms
# Speed: 2.7ms preprocess, 65.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 69.0ms
# Speed: 2.3ms preprocess, 69.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 67.2ms
# Speed: 2.4ms preprocess, 67.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 64.9ms
# Speed: 1.6ms preprocess, 64.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 56.0ms
# Speed: 1.6ms preprocess, 56.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 70.5ms
# Speed: 1.7ms preprocess, 70.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 68.9ms
# Speed: 1.7ms preprocess, 68.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 65.9ms
# Speed: 1.7ms preprocess, 65.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 54.8ms
# Speed: 1.6ms preprocess, 54.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 62.0ms
# Speed: 2.3ms preprocess, 62.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 81.9ms
# Speed: 2.4ms preprocess, 81.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 61.6ms
# Speed: 2.6ms preprocess, 61.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 60.2ms
# Speed: 2.4ms preprocess, 60.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 64.0ms
# Speed: 2.6ms preprocess, 64.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 59.4ms
# Speed: 2.3ms preprocess, 59.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 64.7ms
# Speed: 2.3ms preprocess, 64.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 55.1ms
# Speed: 1.9ms preprocess, 55.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 64.6ms
# Speed: 2.7ms preprocess, 64.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 86.5ms
# Speed: 2.6ms preprocess, 86.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 57.8ms
# Speed: 2.4ms preprocess, 57.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 60.4ms
# Speed: 2.6ms preprocess, 60.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 65.4ms
# Speed: 2.4ms preprocess, 65.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 59.9ms
# Speed: 1.6ms preprocess, 59.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 58.6ms
# Speed: 1.6ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 58.1ms
# Speed: 1.6ms preprocess, 58.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 62.2ms
# Speed: 1.6ms preprocess, 62.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 60.0ms
# Speed: 1.6ms preprocess, 60.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 62.8ms
# Speed: 1.8ms preprocess, 62.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 58.4ms
# Speed: 1.6ms preprocess, 58.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 57.2ms
# Speed: 1.7ms preprocess, 57.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 59.1ms
# Speed: 1.8ms preprocess, 59.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 55.5ms
# Speed: 1.7ms preprocess, 55.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 58.7ms
# Speed: 1.6ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 54.4ms
# Speed: 1.6ms preprocess, 54.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 59.5ms
# Speed: 1.8ms preprocess, 59.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 57.3ms
# Speed: 1.7ms preprocess, 57.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 67.2ms
# Speed: 1.6ms preprocess, 67.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 54.5ms
# Speed: 1.5ms preprocess, 54.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.1ms
# Speed: 1.8ms preprocess, 53.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 55.5ms
# Speed: 1.8ms preprocess, 55.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 59.7ms
# Speed: 1.8ms preprocess, 59.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 61.8ms
# Speed: 1.6ms preprocess, 61.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 56.0ms
# Speed: 1.7ms preprocess, 56.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 57.0ms
# Speed: 1.9ms preprocess, 57.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 51.2ms
# Speed: 1.9ms preprocess, 51.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 61.8ms
# Speed: 1.7ms preprocess, 61.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 79.5ms
# Speed: 1.9ms preprocess, 79.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 53.2ms
# Speed: 1.6ms preprocess, 53.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 58.8ms
# ...
#
# 0: 384x640 1 person, 6 cars, 81.9ms
# Speed: 2.8ms preprocess, 81.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 67.9ms
# Speed: 1.5ms preprocess, 67.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 67.5ms
# Speed: 1.5ms preprocess, 67.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.4ms
# Speed: 2.2ms preprocess, 53.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 50.8ms
# Speed: 1.8ms preprocess, 50.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 67.3ms
# Speed: 1.6ms preprocess, 67.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 70.2ms
# Speed: 1.6ms preprocess, 70.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 57.9ms
# Speed: 2.1ms preprocess, 57.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 73.2ms
# Speed: 1.9ms preprocess, 73.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 68.0ms
# Speed: 1.8ms preprocess, 68.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 74.8ms
# Speed: 1.8ms preprocess, 74.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 67.7ms
# Speed: 1.8ms preprocess, 67.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 71.5ms
# Speed: 1.6ms preprocess, 71.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 52.5ms
# Speed: 1.5ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 66.5ms
# Speed: 1.9ms preprocess, 66.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 66.9ms
# Speed: 1.7ms preprocess, 66.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 87.9ms
# Speed: 3.3ms preprocess, 87.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 82.4ms
# Speed: 1.6ms preprocess, 82.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 69.6ms
# Speed: 1.8ms preprocess, 69.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 74.3ms
# Speed: 1.6ms preprocess, 74.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 76.7ms
# Speed: 1.6ms preprocess, 76.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 67.3ms
# Speed: 1.8ms preprocess, 67.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 55.1ms
# Speed: 1.9ms preprocess, 55.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 68.4ms
# Speed: 1.8ms preprocess, 68.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 60.1ms
# Speed: 1.8ms preprocess, 60.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 67.6ms
# Speed: 1.6ms preprocess, 67.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 53.7ms
# Speed: 1.8ms preprocess, 53.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 63.7ms
# Speed: 1.9ms preprocess, 63.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 77.4ms
# Speed: 1.6ms preprocess, 77.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 72.5ms
# Speed: 1.8ms preprocess, 72.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 57.9ms
# Speed: 1.8ms preprocess, 57.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 61.1ms
# Speed: 1.6ms preprocess, 61.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 86.0ms
# Speed: 1.6ms preprocess, 86.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 74.1ms
# Speed: 1.7ms preprocess, 74.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 80.4ms
# Speed: 1.6ms preprocess, 80.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 98.7ms
# Speed: 1.9ms preprocess, 98.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 74.6ms
# Speed: 1.7ms preprocess, 74.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 67.0ms
# Speed: 1.7ms preprocess, 67.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 51.6ms
# Speed: 1.5ms preprocess, 51.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 75.9ms
# Speed: 1.5ms preprocess, 75.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 52.9ms
# Speed: 1.6ms preprocess, 52.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 59.8ms
# Speed: 1.7ms preprocess, 59.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 79.0ms
# Speed: 1.7ms preprocess, 79.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 53.3ms
# Speed: 1.8ms preprocess, 53.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 78.2ms
# Speed: 1.6ms preprocess, 78.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 67.6ms
# Speed: 1.5ms preprocess, 67.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 85.6ms
# Speed: 1.6ms preprocess, 85.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 68.3ms
# Speed: 1.7ms preprocess, 68.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 64.9ms
# Speed: 1.6ms preprocess, 64.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 58.5ms
# Speed: 2.4ms preprocess, 58.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 61.9ms
# Speed: 1.6ms preprocess, 61.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 68.6ms
# Speed: 1.6ms preprocess, 68.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 58.3ms
# Speed: 1.6ms preprocess, 58.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 51.9ms
# Speed: 1.6ms preprocess, 51.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 54.6ms
# Speed: 1.5ms preprocess, 54.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 74.2ms
# Speed: 1.5ms preprocess, 74.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 49.6ms
# Speed: 1.6ms preprocess, 49.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 69.9ms
# Speed: 1.9ms preprocess, 69.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 66.5ms
# Speed: 1.7ms preprocess, 66.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 81.0ms
# Speed: 1.7ms preprocess, 81.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.9ms
# Speed: 1.7ms preprocess, 53.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 54.3ms
# Speed: 1.7ms preprocess, 54.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 71.1ms
# Speed: 2.4ms preprocess, 71.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 54.2ms
# Speed: 1.9ms preprocess, 54.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 52.1ms
# Speed: 2.3ms preprocess, 52.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 63.9ms
# Speed: 2.5ms preprocess, 63.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 79.6ms
# Speed: 1.6ms preprocess, 79.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 71.5ms
# Speed: 1.6ms preprocess, 71.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 89.4ms
# Speed: 2.5ms preprocess, 89.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 53.2ms
# Speed: 1.7ms preprocess, 53.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 55.8ms
# Speed: 1.7ms preprocess, 55.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 96.6ms
# Speed: 2.2ms preprocess, 96.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 52.6ms
# Speed: 1.6ms preprocess, 52.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 52.5ms
# Speed: 1.7ms preprocess, 52.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 53.3ms
# Speed: 1.7ms preprocess, 53.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 72.1ms
# Speed: 3.2ms preprocess, 72.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 92.8ms
# Speed: 3.3ms preprocess, 92.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 80.4ms
# Speed: 1.8ms preprocess, 80.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 99.2ms
# Speed: 1.6ms preprocess, 99.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 69.7ms
# Speed: 1.8ms preprocess, 69.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 65.7ms
# Speed: 1.8ms preprocess, 65.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 71.0ms
# Speed: 1.6ms preprocess, 71.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 96.6ms
# Speed: 2.4ms preprocess, 96.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 67.8ms
# Speed: 1.7ms preprocess, 67.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 68.5ms
# Speed: 1.9ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 68.4ms
# Speed: 1.6ms preprocess, 68.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 69.4ms
# Speed: 1.8ms preprocess, 69.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 90.1ms
# Speed: 1.6ms preprocess, 90.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 62.0ms
# Speed: 1.5ms preprocess, 62.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 64.7ms
# Speed: 1.5ms preprocess, 64.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 77.4ms
# Speed: 1.8ms preprocess, 77.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 73.1ms
# Speed: 1.9ms preprocess, 73.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 74.0ms
# Speed: 1.9ms preprocess, 74.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 64.8ms
# Speed: 2.1ms preprocess, 64.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 67.0ms
# Speed: 2.1ms preprocess, 67.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 77.8ms
# Speed: 1.5ms preprocess, 77.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ==== TOTALES ÚNICOS ====
# license plates: 4
# persons: 21
# cars: 81
# motorcycles: 2
# buses: 3
